# %%
import pandas as pd
import numpy as np
import os
data = "../data/"

# %%
sources = pd.read_csv(os.path.join(data,"external", "iffy+.csv"))
included_sources = pd.read_csv(os.path.join(data,"external", "included_domains.csv"))

all_networks = pd.read_csv(os.path.join(data, "raw", "all_networks.csv"))
graph_data = pd.read_pickle(os.path.join(data, "processed", "graph_data.pkl"))
cluster_data = pd.read_pickle(os.path.join("../models", "graphs_clustered.pkl"))

# %%
sources
# Out:
#                   Domain MBFC MBFC factual   BF  FC   PF  WI  Site Rank  \
# 0    100percentfedup.com   FN            L  NaN NaN  NaN NaN     101963
# 1             10news.one   FN            L  NaN NaN  NaN NaN    2688331
# 2          12minutos.com   FN            L  1.0 NaN  NaN NaN     330294
# 3    21stcenturywire.com   CP            M  NaN NaN  NaN NaN     131699
# 4        24aktuelles.com  NaN          NaN  1.0 NaN  NaN NaN    1138388
# ..                   ...  ...          ...  ...  ..  ...  ..        ...
# 807        x22report.com   CP            L  NaN NaN  NaN NaN     172647
# 808              yc.news   FN            M  NaN NaN  NaN NaN     588428
# 809       yesimright.com   FN            L  NaN NaN  NaN NaN    1510426
# 810          zenith.news   FN            L  NaN NaN  NaN NaN    1350732
# 811        zerohedge.com   CP            L  NaN NaN  NaN NaN       1812
#
#      Yr online                        Name  \
# 0          NaN          100 Percent Fed Up
# ...

# %%
included_sources
# Out:
#     Unnamed: 0               articles
# 0            0       activistpost.com
# 1            1           albawaba.com
# 2            2    americanthinker.com
# 3            3           arabnews.com
# 4            4  bigleaguepolitics.com
# ..         ...                    ...
# 85          85        waynedupree.com
# 86          86               whale.to
# 87          87                wnd.com
# 88          88    worldstarhiphop.com
# 89          89          zerohedge.com
#
# [90 rows x 2 columns]

# %%
all_networks.domain.value_counts()
# Out:
# trendingpolitics.com    4594
# wattsupwiththat.com     1923
# thenationalpulse.com    1532
# oann.com                1411
# swarajyamag.com         1344
#                         ...
# perezhilton.com            5
# wnd.com                    4
# redstate.com               4
# neonnettle.com             2
# cair.com                   2
# Name: domain, Length: 73, dtype: int64

# %%
all_networks.id.value_counts()
# Out:
# 2635421    1392
# 2766016    1350
# 2671830     660
# 2681870     584
# 2585351     516
#            ...
# 2585394       1
# 2560862       1
# 2718188       1
# 2573172       1
# 2590475       1
# Name: id, Length: 1957, dtype: int64

# %%
graph_data.id.value_counts()
# Out:
# 2586622    1
# 2590221    1
# 2576746    1
# 2607465    1
# 2570599    1
#           ..
# 2580144    1
# 2869943    1
# 2869944    1
# 2589092    1
# 2575979    1
# Name: id, Length: 569, dtype: int64
