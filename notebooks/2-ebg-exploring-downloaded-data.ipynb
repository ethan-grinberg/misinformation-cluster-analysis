# %%
import pandas as pd
import numpy as np

# %%
path = "../data/external/"
all_claims = pd.read_csv(path+"all_claim_reviews.csv")
all_countries = pd.read_csv(path+"all_countries.csv")
all_keywords = pd.read_csv(path+"all_keywords.csv")
all_languages = pd.read_csv(path+"all_languages.csv")
all_news_articles = pd.read_csv(path+"all_news_articles.csv")
all_organizations = pd.read_csv(path+"all_organisations.csv")
claims_w_sent = pd.read_csv(path+"claims_w_sent.csv")

# %%
claims_w_sent
# Out:
#       Unnamed: 0                   id                           type  \
# 0           7441  /claim_reviews/8389  http://schema.org/ClaimReview
# 1           7200  /claim_reviews/8142  http://schema.org/ClaimReview
# 2           7201  /claim_reviews/8143  http://schema.org/ClaimReview
# 3           7202  /claim_reviews/8144  http://schema.org/ClaimReview
# 4           7203  /claim_reviews/8145  http://schema.org/ClaimReview
# ...          ...                  ...                            ...
# 7009          12    /claim_reviews/45  http://schema.org/ClaimReview
# 7010          13    /claim_reviews/46  http://schema.org/ClaimReview
# 7011          14    /claim_reviews/48  http://schema.org/ClaimReview
# 7012           7    /claim_reviews/37  http://schema.org/ClaimReview
# 7013           0    /claim_reviews/20  http://schema.org/ClaimReview
#
#                                           claimReviewed  reviewRating  \
# 0     Lviv university: Students using Russian social...           NaN
# 1     USA insist that Right Sector takes part in the...           NaN
# 2     Ukraine will not return the 3 billion USD debt...           NaN
# 3     Last Week's Trend: Ukraine provides ISIS with ...           NaN
# 4     Last Week's Trend: The Islamic State steals Ir...           NaN
# ...                                                 ...           ...
# 7009  Four officers of Ukraine's Security Service we...           NaN
# 7010  US satellites were supposed to “see” the momen...           NaN
# 7011  Venezuela’s National Assembly decided to suspe...           NaN
# 7012  Ukraine allowed citizenship to be issued to mu...           NaN
# 7013  There are British curators behind the persecut...           NaN
#
#                   datePublished  itemReviewed  \
# 0     2015-01-06 00:00:00+00:00  /claims/8389
# 1     2015-12-09 00:00:00+00:00  /claims/8142
# 2     2015-12-09 00:00:00+00:00  /claims/8143
# 3     2015-12-09 00:00:00+00:00  /claims/8144
# 4     2015-12-09 00:00:00+00:00  /claims/8145
# ...                         ...           ...
# 7009  2020-01-03 00:00:00+00:00    /claims/45
# 7010  2020-01-03 00:00:00+00:00    /claims/46
# 7011  2020-01-02 00:00:00+00:00    /claims/48
# 7012  2020-01-05 00:00:00+00:00    /claims/37
# 7013  2020-01-07 00:00:00+00:00    /claims/20
#
#                                                    name  \
# 0     Lviv university: Students using Russian social...
# 1     USA insist that Right Sector takes part in the...
# 2     Ukraine will not return the 3 billion USD debt...
# 3     Last Week's Trend: Ukraine provides ISIS with ...
# 4     Last Week's Trend: The Islamic State steals Ir...
# ...                                                 ...
# 7009  Four Ukrainian security officers were shot on ...
# 7010  US does not provide satellite images to JIT on...
# 7011  Juan Guaidó involved in the big corruption sch...
# 7012        Ukraine will issue citizenship to murderers
# 7013  British curators are behind the persecution of...
#
#                                               html_text  \
# 0     <p>The lecturer himself told that in accordanc...
# 1     <p>Based on false quotation of Vice President ...
# 2     <p>Ukraine has proposed debt restructuring: ht...
# 3     <p>Repeating already debunked disinformation a...
# 4     <p>Repeating an older disinformation. No evide...
# ...                                                 ...
# 7009  <p>No evidence given except anonymous sources....
# 7010  <p>No evidence given. This claim is a part of ...
# 7011  <p>This is a deliberate distortion of facts in...
# 7012  <p><span style="font-weight: 400;">This is a r...
# 7013  <p>This conspiracy theory is based on the conc...
#
#                                                    text  ... yearPublished  \
# 0     The lecturer himself told that in accordance w...  ...          2015
# 1     Based on false quotation of Vice President Joe...  ...          2015
# 2     Ukraine has proposed debt restructuring: WEBSI...  ...          2015
# 3     Repeating already debunked disinformation abou...  ...          2015
# 4     Repeating an older disinformation. No evidence...  ...          2015
# ...                                                 ...  ...           ...
# 7009  No evidence given except anonymous sources. Se...  ...          2020
# 7010  No evidence given. This claim is a part of a r...  ...          2020
# 7011  This is a deliberate distortion of facts in or...  ...          2020
# 7012  This is a recurring narrative that Kyiv favour...  ...          2020
# 7013  This conspiracy theory is based on the concept...  ...          2020
#
#            country1         keyword1  umap_embedding_0 umap_embedding_1  \
# 0            Russia             Lviv         -1.108813        -2.653256
# 1                US           Donbas         -5.405421        10.368729
# 2            Russia  Dmitry Medvedev          7.903592         0.856451
# 3           Ukraine            Daesh          1.951833         4.662179
# 4              Iraq            Daesh          6.544899        -0.474692
# ...             ...              ...               ...              ...
# 7009        Ukraine          Ukraine        -10.908116        -7.674587
# 7010  United States           Donbas         -5.205469        -8.589635
# 7011      Venezuela      Juan Guaido          3.118076        -0.809468
# 7012        Ukraine           Donbas          4.627163         3.566092
# 7013        Estonia  Dmitry Kiselyov         -1.573363        -3.522353
#
#      tfidf_embedding_0  tfidf_embedding_1  sentiment  polarity  subjectivity
# 0             2.983241           4.831746  -0.998350  0.016667      0.033333
# 1            -1.827649          -1.763807   0.600528  0.285714      0.535714
# 2            -0.597539          -3.476776   0.881517  0.000000      0.000000
# 3            -0.574923          -3.473153  -0.889897  0.000000      0.066667
# 4             0.228640          -0.884205   0.990830  0.000000      0.066667
# ...                ...                ...        ...       ...           ...
# 7009         -0.153923          -0.145442   0.998511 -0.050000      0.200000
# 7010         -3.699373          -1.013517  -0.995853  0.200000      0.200000
# 7011         -1.495803           0.095340  -0.674158  0.033333      0.100000
# 7012          0.688219           2.588677   0.959138  0.000000      0.000000
# 7013          0.774305          -0.824603   0.983887 -0.200000      0.350000
#
# [7014 rows x 23 columns]

# %%
all_claims
# Out:
#       Unnamed: 0                  @id                          @type  \
# 0              1    /claim_reviews/20  http://schema.org/ClaimReview
# 1              2    /claim_reviews/21  http://schema.org/ClaimReview
# 2              3    /claim_reviews/22  http://schema.org/ClaimReview
# 3              4    /claim_reviews/24  http://schema.org/ClaimReview
# 4              5    /claim_reviews/33  http://schema.org/ClaimReview
# ...          ...                  ...                            ...
# 7223        7224  /claim_reviews/8385  http://schema.org/ClaimReview
# 7224        7225  /claim_reviews/8386  http://schema.org/ClaimReview
# 7225        7226  /claim_reviews/8387  http://schema.org/ClaimReview
# 7226        7227  /claim_reviews/8388  http://schema.org/ClaimReview
# 7227        7228  /claim_reviews/8389  http://schema.org/ClaimReview
#
#                                           claimReviewed  reviewRating  \
# 0     There are British curators behind the persecut...           NaN
# 1     I would like to add that, as far as I know, Sp...           NaN
# 2     We regard the actions of the regime in Estonia...           NaN
# 3     The only thing we are guilty of is the fact th...           NaN
# 4     Using the enormous archive of trophy documents...           NaN
# ...                                                 ...           ...
# 7223  Massive rally against NATO membership took pla...           NaN
# 7224  The migration crisis is a US-led operation wit...           NaN
# 7225  The Ukrainian revolution was organized by the ...           NaN
# 7226  There is a state-supported national tradition ...           NaN
# 7227  Lviv university: Students using Russian social...           NaN
#
#                   datePublished  itemReviewed  \
# 0     2020-01-07T00:00:00+00:00    /claims/20
# 1     2020-01-07T00:00:00+00:00    /claims/21
# 2     2020-01-07T00:00:00+00:00    /claims/22
# 3     2020-01-07T00:00:00+00:00    /claims/24
# 4     2020-01-06T00:00:00+00:00    /claims/33
# ...                         ...           ...
# 7223  2015-03-11T00:00:00+00:00  /claims/8385
# 7224  2015-02-11T00:00:00+00:00  /claims/8386
# 7225  2015-02-11T00:00:00+00:00  /claims/8387
# 7226  2015-01-25T00:00:00+00:00  /claims/8388
# 7227  2015-01-06T00:00:00+00:00  /claims/8389
#
#                                                    name  \
# 0     British curators are behind the persecution of...
# 1                 There are no lies coming from Sputnik
# 2     The regime in Estonia publicly persecutes its ...
# 3              There is no freedom of speech in Estonia
# 4                           Poland started World War II
# ...                                                 ...
# 7223  Massive rally against NATO membership took pla...
# 7224  The migration crisis is a US-led operation wit...
# 7225  The Ukrainian revolution was organized by the ...
# 7226  There is a state-supported national tradition ...
# 7227  Lviv university: Students using Russian social...
#
#                                                    text
# 0     <p>This conspiracy theory is based on the conc...
# 1     <p><a href="https://euvsdisinfo.eu/three-thing...
# 2     <p>Estonia is ranked as the <a href="https://r...
# 3     <p>As for the freedom of speech, Estonia is in...
# 4     <p>Historical revisionism consistent with recu...
# ...                                                 ...
# 7223  <p>The image Slobodni Mediji uses to illustrat...
# 7224  <p>Repeating an older disinformation with no s...
# 7225  <p>Repeating disinformation that has been debu...
# 7226  <p>Disinformation with origins in 2013 targeti...
# 7227  <p>The lecturer himself told that in accordanc...
#
# [7228 rows x 9 columns]

# %%
all_countries
# Out:
#      Unnamed: 0             @id                      @type           name
# 0             1    /countries/1  http://schema.org/Country          Qatar
# 1             2    /countries/2  http://schema.org/Country           Iran
# 2             3    /countries/3  http://schema.org/Country  United States
# 3             4    /countries/4  http://schema.org/Country         Russia
# 4             5    /countries/5  http://schema.org/Country           Iraq
# ..          ...             ...                        ...            ...
# 114         115  /countries/115  http://schema.org/Country          Yemen
# 115         116  /countries/116  http://schema.org/Country     David Icke
# 116         117  /countries/117  http://schema.org/Country       Al-Qaeda
# 117         118  /countries/118  http://schema.org/Country          Daesh
# 118         119  /countries/119  http://schema.org/Country           Mali
#
# [119 rows x 4 columns]

# %%
all_keywords
# Out:
#      Unnamed: 0            @id                          @type  \
# 0             1    /keywords/1  http://schema.org/DefinedTerm
# 1             2    /keywords/2  http://schema.org/DefinedTerm
# 2             3    /keywords/3  http://schema.org/DefinedTerm
# 3             4    /keywords/4  http://schema.org/DefinedTerm
# 4             5    /keywords/5  http://schema.org/DefinedTerm
# ..          ...            ...                            ...
# 603         604  /keywords/604  http://schema.org/DefinedTerm
# 604         605  /keywords/605  http://schema.org/DefinedTerm
# 605         606  /keywords/606  http://schema.org/DefinedTerm
# 606         607  /keywords/607  http://schema.org/DefinedTerm
# 607         608  /keywords/608  http://schema.org/DefinedTerm
#
#                     name
# 0              fake news
# 1    Russian superiority
# 2         Western values
# 3             Conspiracy
# 4                   NATO
# ..                   ...
# 603         Viktor Gvozd
# 604      The Independent
# 605     Rosen Plevneliev
# 606        David Cameron
# 607            Le Figaro
#
# [608 rows x 4 columns]

# %%
all_languages
# Out:
#     Unnamed: 0            @id                       @type                name  \
# 0            1   /languages/1  http://schema.org/Language              Arabic
# 1            2   /languages/2  http://schema.org/Language            Armenian
# 2            3   /languages/3  http://schema.org/Language             Russian
# 3            4   /languages/4  http://schema.org/Language           Hungarian
# 4            5   /languages/5  http://schema.org/Language              French
# 5            6   /languages/6  http://schema.org/Language  Spanish, Castilian
# 6            7   /languages/7  http://schema.org/Language             English
# 7            8   /languages/8  http://schema.org/Language             Italian
# 8            9   /languages/9  http://schema.org/Language            Estonian
# 9           10  /languages/10  http://schema.org/Language             Serbian
# 10          11  /languages/11  http://schema.org/Language             Bosnian
# 11          12  /languages/12  http://schema.org/Language             Finnish
# 12          13  /languages/13  http://schema.org/Language              German
# 13          14  /languages/14  http://schema.org/Language              Polish
# 14          15  /languages/15  http://schema.org/Language            Georgian
# 15          16  /languages/16  http://schema.org/Language               Czech
# 16          17  /languages/17  http://schema.org/Language            Croatian
# 17          18  /languages/18  http://schema.org/Language          Macedonian
# 18          19  /languages/19  http://schema.org/Language         Montenegrin
# 19          20  /languages/20  http://schema.org/Language           Ukrainian
# 20          21  /languages/21  http://schema.org/Language            Romanian
# 21          22  /languages/22  http://schema.org/Language           Moldavian
# 22          23  /languages/23  http://schema.org/Language           Abkhazian
# 23          24  /languages/24  http://schema.org/Language         Azerbaijani
# 24          25  /languages/25  http://schema.org/Language          Belarusian
# 25          26  /languages/26  http://schema.org/Language          Lithuanian
# 26          27  /languages/27  http://schema.org/Language                 blr
# 27          28  /languages/28  http://schema.org/Language                 mne
# 28          29  /languages/29  http://schema.org/Language                 mda
# 29          30  /languages/30  http://schema.org/Language                 lva
# 30          31  /languages/31  http://schema.org/Language                 srb
# 31          32  /languages/32  http://schema.org/Language                 rou
# 32          33  /languages/33  http://schema.org/Language                 deu
# 33          34  /languages/34  http://schema.org/Language                 ltu
# 34          35  /languages/35  http://schema.org/Language             Latvian
# 35          36  /languages/36  http://schema.org/Language              Slovak
# 36          37  /languages/37  http://schema.org/Language                 bgr
# 37          38  /languages/38  http://schema.org/Language             Swedish
#
#    alternateName
# 0            ara
# 1            arm
# 2            rus
# 3            hun
# 4            fra
# 5            spa
# 6            eng
# 7            ita
# 8            est
# 9            srp
# 10           bos
# 11           fin
# 12           ger
# 13           pol
# 14           geo
# 15           cze
# 16           hrv
# 17           mkd
# 18           cnr
# 19           ukr
# 20           rum
# 21           mol
# 22           abk
# 23           aze
# 24           bel
# 25           lit
# 26           blr
# 27           mne
# 28           mda
# 29           lva
# 30           srb
# 31           rou
# 32           deu
# 33           ltu
# 34           lav
# 35           svk
# 36           bgr
# 37           swe

# %%
all_news_articles
# Out:
#       Unnamed: 0                  @id                          @type  \
# 0              1   /news_articles/121  http://schema.org/NewsArticle
# 1              2   /news_articles/122  http://schema.org/NewsArticle
# 2              3   /news_articles/123  http://schema.org/NewsArticle
# 3              4   /news_articles/126  http://schema.org/NewsArticle
# 4              5   /news_articles/195  http://schema.org/NewsArticle
# ...          ...                  ...                            ...
# 5622        5623  /news_articles/8954  http://schema.org/NewsArticle
# 5623        5624  /news_articles/8955  http://schema.org/NewsArticle
# 5624        5625  /news_articles/8956  http://schema.org/NewsArticle
# 5625        5626  /news_articles/8957  http://schema.org/NewsArticle
# 5626        5627  /news_articles/8958  http://schema.org/NewsArticle
#
#                                                     url  name  datePublished  \
# 0     https://sputnik-news.ee/politics/20191226/1885...   NaN            NaN
# 1     https://sputnik-news.ee/estonian_news/20191228...   NaN            NaN
# 2     https://sputnik-news.ee/estonian_news/20191231...   NaN            NaN
# 3     https://sputnik-news.ee/estonian_news/20200101...   NaN            NaN
# 4     https://az.sputniknews.ru/russia/20191226/4227...   NaN            NaN
# ...                                                 ...   ...            ...
# 5622  http://www.casopis-sifra.cz/nikolaj-starikov-p...   NaN            NaN
# 5623  http://www.biosferaklub.info/co-se-na-nas-hrne...   NaN            NaN
# 5624  http://www.czechfreepress.cz/evropa/co-se-na-n...   NaN            NaN
# 5625  http://leva-net.webnode.cz/products/preklad-ro...   NaN            NaN
# 5626  http://truthhunter1.blogspot.cz/2015/01/media-...   NaN            NaN
#
#                    author         claim  \
# 0       /organizations/90    /claims/20
# 1       /organizations/90    /claims/21
# 2       /organizations/90    /claims/22
# 3       /organizations/90    /claims/24
# 4      /organizations/125    /claims/35
# ...                   ...           ...
# 5622   /organizations/752  /claims/8387
# 5623  /organizations/1153  /claims/8388
# 5624   /organizations/870  /claims/8388
# 5625  /organizations/1195  /claims/8388
# 5626  /organizations/1260  /claims/8388
#
#                                           webArchiveUrl  \
# 0     https://web.archive.org/web/20200107173925/htt...
# 1     https://web.archive.org/web/20200107170137/htt...
# 2                                                   NaN
# 3     https://web.archive.org/web/20200107144351/htt...
# 4     https://web.archive.org/web/20200106061011/htt...
# ...                                                 ...
# 5622                                                NaN
# 5623                                                NaN
# 5624                                                NaN
# 5625                                                NaN
# 5626                                                NaN
#
#                                                abstract    inLanguage
# 0     Eesti võimude tegevuse taga Sputniku tagakiusa...  /languages/9
# 1     Siinkohal sooviksin lisada, et Sputnik Eesti v...  /languages/9
# 2     Peame Eesti režiimi tegevust oma riigi kodanik...  /languages/9
# 3     Meie ainus "süü" on selles, et oleme ajakirjan...  /languages/9
# 4     "Вот эта травля, настоящая травля, которая сей...  /languages/3
# ...                                                 ...           ...
# 5622                                                NaN           NaN
# 5623                                                NaN           NaN
# 5624                                                NaN           NaN
# 5625                                                NaN           NaN
# 5626                                                NaN           NaN
#
# [5627 rows x 11 columns]

# %%
all_organizations
# Out:
#       Unnamed: 0                  @id                           @type  \
# 0              1     /organizations/1  http://schema.org/Organization
# 1              2     /organizations/2  http://schema.org/Organization
# 2              3     /organizations/3  http://schema.org/Organization
# 3              4     /organizations/4  http://schema.org/Organization
# 4              5     /organizations/5  http://schema.org/Organization
# ...          ...                  ...                             ...
# 1255        1256  /organizations/1256  http://schema.org/Organization
# 1256        1257  /organizations/1257  http://schema.org/Organization
# 1257        1258  /organizations/1258  http://schema.org/Organization
# 1258        1259  /organizations/1259  http://schema.org/Organization
# 1259        1260  /organizations/1260  http://schema.org/Organization
#
#           location                      name  sameAs  creativeWorksCount
# 0              NaN            Sputnik Arabic     NaN                 NaN
# 1              NaN                 RT Arabic     NaN                 NaN
# 2              NaN                elbashayer     NaN                 NaN
# 3              NaN        medianetworkagency     NaN                 NaN
# 4              NaN                   Rt Arab     NaN                 NaN
# ...            ...                       ...     ...                 ...
# 1255  /countries/4           sputniknews.com     NaN                 NaN
# 1256           NaN                     nv.ua     NaN                 NaN
# 1257           NaN           webnovosti.info     NaN                 NaN
# 1258  /countries/4           sputniknews.com     NaN                 NaN
# 1259           NaN  truthhunter1.blogspot.cz     NaN                 NaN
#
# [1260 rows x 7 columns]
