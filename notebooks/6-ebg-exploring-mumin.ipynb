# %%
import pandas as pd
import numpy as np
import os
from mumin import MuminDataset
from dotenv import find_dotenv, load_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
dataset = MuminDataset(twitter_bearer_token=os.environ['BEARERTOKEN'])
dataset
# Out:
# MuminDataset(size=small, compiled=False, bearer_token_available=True)

# %%
os.environ['BEARERTOKEN']
# Out:
# 'AAAAAAAAAAAAAAAAAAAAADjYcwEAAAAAiFvyuecrWQ3pVGeBvC40vkFC0Vw%3DU6dvvJHnMBrtAOTffpOzgmhtfjKfaEE776NHZS7z7D8qpr82EB'

# %%
dataset.compile()
# Out:
# 2022-05-24 19:49:38,986 [INFO] Loading dataset
# 2022-05-24 19:49:43,442 [INFO] Shrinking dataset
# 2022-05-24 19:49:44,154 [INFO] Rehydrating tweet nodes
# Rehydrating:   0%|          | 0/5261 [00:00<?, ?it/s]
# ...
